# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import pandas as pd

data = pd.read_json("../data.json")
data.sample(2)
# Out:
#        index           mac                        timestamp  no  rssi  \
# 14006    133  c300000a7a46 2024-11-10 18:42:59.708000+00:00   0   -77
# 8710      96  c300000a7a48 2024-10-26 10:44:38.701000+00:00   0   -52
#
#                                                      raw  frequency  \
# 14006  0201061bff3906cafb01140002ffef0107000000000000...       2480
# 8710   0201061bff3906cafb01140005ffec0100000000000000...       2426
#
#                                                       iq  angle    distance  \
# 14006  [-68, 53, -51, -75, 75, -45, 19, 76, -72, -2, ...      0  750.000000
# 8710   [-133, -106, 116, -120, 109, 124, -148, 76, -5...    120  121.243557
#
#       capture                                                ref  \
# 14006  camila  [2.4795321911, -2.1679729849, -0.5404195003, 1...
# 8710     poli  [-2.4686882566, -0.8023456932, 0.8496871288000...
#
#                                                       a1  \
# 14006  [2.7626129928000003, 0.3300606124, -1.92517624...
# 8710   [1.4407649505, -0.9827937232, 2.9356013169, 0....
#
#                                                       a2  \
# 14006  [-2.6011731533, 1.6247978272, -0.7610127542, -...
# 8710   [-0.6542405527, -2.8821432206, 0.9933567107000...
#
#                                                       a3  \
# 14006  [-2.5415424401999998, 1.8337910585000001, -0.6...
# 8710   [-1.8964379121000001, 1.9317424831, -0.4106247...
#
#                                                     a2a1  \
# 14006  [0.9193991610000001, 1.2947372148, 1.164163491...
# 8710   [-2.0950055031, -1.8993494973, -1.9422446063, ...
#
#                                                     a3a2  \
# 14006  [0.0596307131, 0.2089932313, 0.132216467800000...
# 8710   [-1.2421973594, -1.4692996035, -1.4039814399, ...
#
#                                                     a3a1
# 14006  [0.9790298741000001, 1.5037304461, 1.296379959...
# 8710   [2.9459824446000002, 2.9145362064, 2.936959261...
