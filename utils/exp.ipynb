# %%
import pandas as pd
from utils import single_antenna_to_dataframe

# %%
single_antenna_to_dataframe("./2-2-0-5-1-12.json")
# Out:
#               mac                 timestamp  no  rssi  \
# 0    ac233f7728a7  2024-07-29T16:50:43.111Z   1   -50
# 1    ac233f7728a7  2024-07-29T16:50:44.211Z   1   -41
# 2    ac233f7728a7  2024-07-29T16:50:45.237Z   1   -48
# 3    ac233f7728a7  2024-07-29T16:50:46.264Z   1   -42
# 4    ac233f7728a7  2024-07-29T16:50:47.279Z   1   -41
# ..            ...                       ...  ..   ...
# 115  ac233f7728a7  2024-07-29T16:52:38.099Z   1   -50
# 116  ac233f7728a7  2024-07-29T16:52:39.025Z   1   -49
# 117  ac233f7728a7  2024-07-29T16:52:40.041Z   1   -42
# 118  ac233f7728a7  2024-07-29T16:52:40.958Z   1   -41
# 119  ac233f7728a7  2024-07-29T16:52:41.985Z   1   -48
#
#                                           raw  frequency  \
# 0    02010605ff3906cafb0a094d696e657720416f41       2480
# 1    02010605ff3906cafb0a094d696e657720416f41       2426
# 2    02010605ff3906cafb0a094d696e657720416f41       2480
# 3    02010605ff3906cafb0a094d696e657720416f41       2402
# ...
